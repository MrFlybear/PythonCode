# %%
#行不通因为前面有登陆界面
'''
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time,sys
browser = webdriver.Firefox()
browser.get('http://www.gdhy.gov.cn/common.do?do=getWdrqxx&yyrq=2019-06-28&blcs=440300000000&ywlx=J')
'''
#0.登陆微信
import itchat
import datetime
import time
itchat.auto_login(hotReload=True)
#查找发信人
users=itchat.search_friends(name='cmt')
userName=users[0]['UserName']
#itchat.send('交d费%s',toUserName=userName)
#使用gui
#1.切换到查询界面
import time,os,pyautogui
os.chdir(r'C:\Users\xxcmt\Desktop\文档\automate_online-materials')
print('微信登陆成功，开始切换')
time.sleep(3)
#2.点击查询按键，每2分钟点击一次
while True:
    pyautogui.click(1222,787)
    time.sleep(120)
    zero=pyautogui.locateOnScreen('zero.PNG')
    if zero!=None:
        print('还是零')
        itchat.send('还是零',toUserName=userName)
    else:
        itchat.send('速度预约',toUserName=userName)
        itchat.send('速度预约',toUserName=userName)
        itchat.send('速度预约',toUserName=userName)
        itchat.send('速度预约',toUserName=userName)
        itchat.send('速度预约',toUserName=userName)
# Out:
# Getting uuid of QR code.
# ...
# LOG OUT!
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as 熊
# 微信登陆成功，开始切换
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# 还是零
# LOG OUT!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ...
