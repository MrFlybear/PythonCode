# %%
import smtplib
smtpObj=smtplib.SMTP('smtp.qq.com',587)
smtpObj.ehlo()
smtpObj.starttls()
#要开启SMTP获得授权码
smtpObj.login('1036433209@qq.com','ztmgnjogoyjhbedh')
str2='abc'
strtest='Subject:test.\n'+str2
smtpObj.sendmail('1036433209@qq.com','1754690142@qq.com',strtest)
smtpObj.quit()
# Out:
# (221, b'Bye')

# %%
import imapclient,pprint
imapObj=imapclient.IMAPClient('imap.qq.com',ssl=True)
imapObj.login('1036433209@qq.com','zgckbsunfdgwbddh')
#显示有什么文件夹
pprint.pprint(imapObj.list_folders())
imapObj.select_folder('INBOX',readonly=True)
#len(imapObj.search(['ALL']))
#应该是协议问题反正不行，显示邮件uid
pprint.pprint(imapObj.search(['SINCE 19 May 2019']))
rawMessages=imapObj.fetch(423,['BODY[]'])
import pprint
#查看邮件字典关键字
pprint.pprint(rawMessages)
import pyzmail
message=pyzmail.PyzMessage.factory(rawMessages[423][b'BODY[]'])
#获得邮件主题
print(message.get_subject())
if message.text_part!=None:
    print(message.text_part.get_payload().decode('UTF-8'))
#if message.html_part != None:
#    print(message.html_part.get_payload().decode(message.html_part.charset))
#获得邮件纯文本
#message.text_part.get_payload().decode(message.text_part.charset)
#message.html_part!=None
#message.html_part.get_payload().decode(message.html_part.charset)
#删除邮件
#imapObj.delete_messages(1)
#imapObj.expunge()
#退出
#imapObj.logout()
# Out:
# [((b'\\NoSelect', b'\\HasChildren'), b'/', '其他文件夹'),
#  ((b'\\HasNoChildren',), b'/', 'INBOX'),
#  ((b'\\HasNoChildren',), b'/', 'Sent Messages'),
#  ((b'\\HasNoChildren',), b'/', 'Drafts'),
#  ((b'\\HasNoChildren',), b'/', 'Deleted Messages'),
#  ((b'\\HasNoChildren',), b'/', 'Junk'),
#  ((b'\\HasNoChildren',), b'/', '其他文件夹/xiong'),
#  ((b'\\HasNoChildren',), b'/', '其他文件夹/QQ邮件订阅'),
#  ((b'\\HasNoChildren',), b'/', '其他文件夹/xiang')]
# [117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  132,
#  133,
#  134,
#  135,
#  136,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
# ...

# %%
'''

'''
