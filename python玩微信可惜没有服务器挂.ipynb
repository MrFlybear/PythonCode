# %%
import itchat
import datetime
import time
itchat.auto_login(hotReload=True)
partydues_dict={'张柳':'87.5','戴文博':'96','黄如杰':'94','黄永亮':'94.5','谭何顺':'105'}
#查找发信人
for uname,msg in partydues_dict.items():
    users=itchat.search_friends(name=uname)
    userName=users[0]['UserName']
    itchat.send('交d费%s'msg,toUserName=userName)
    print('the bill has notified to %s，%s'%(uname,msg))
# Out:
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797330699&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797330699 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797330699&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797330699 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797330771&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797330771 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797330771&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797330771 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797330751&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797330751 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797330751&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797330751 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797332246&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797332246 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797332246&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797332246 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797332237&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797332237 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797332237&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797332237 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797332289&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797332289 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797332289&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797332289 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797333326&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797333326 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797333326&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797333326 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797333321&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797333321 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797333321&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797333321 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797333377&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797333377 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797333377&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797333377 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797334404&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797334404 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797334404&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797334404 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797334415&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797334415 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797334415&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797334415 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# ...
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797335526&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797335526 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797335526&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797335526 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797336548&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797336548 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797336548&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797336548 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797336556&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797336556 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797336556&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797336556 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
#
# LOG OUT!
# LOG OUT!
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 453, in wrap_socket
#     cnx.do_handshake()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1915, in do_handshake
#     self._raise_ssl_error(self._ssl, result)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 1640, in _raise_ssl_error
#     raise SysCallError(-1, "Unexpected EOF")
# OpenSSL.SSL.SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 594, in urlopen
#     self._prepare_proxy(conn)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 805, in _prepare_proxy
#     conn.connect()
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connection.py", line 344, in connect
#     ssl_context=context)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\ssl_.py", line 344, in ssl_wrap_socket
#     return context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 459, in wrap_socket
#     raise ssl.SSLError('bad handshake: %r' % e)
# ssl.SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 449, in send
#     timeout=timeout
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\urllib3\util\retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797336585&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797336585 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 303, in sync_check
#     r = self.s.get(url, params=params, headers=headers, timeout=config.TIMEOUT)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 546, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\requests\adapters.py", line 514, in send
#     raise SSLError(e, request=request)
# requests.exceptions.SSLError: HTTPSConnectionPool(host='webpush.wx2.qq.com', port=443): Max retries exceeded with url: /cgi-bin/mmwebwx-bin/synccheck?r=1557797336585&skey=%40crypt_8157b8c0_74d1ae3c7ec89467313b9198e5876bf9&sid=LV38yrC6RTdhtbFM&uin=2252065263&deviceid=e809137170699218&synckey=1_692371205%7C2_692371222%7C3_692371187%7C11_692370838%7C201_1557795743%7C1000_1557790399%7C1001_1557790402&_=1557797336585 (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')")))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 247, in maintain_loop
#     i = sync_check(self)
#   File "C:\Users\xxcmt\Anaconda3\lib\site-packages\itchat\components\login.py", line 306, in sync_check
#     if not isinstance(e.args[0].args[1], BadStatusLine):
# IndexError: tuple index out of range
# LOG OUT!
